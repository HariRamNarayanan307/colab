# %% [markdown]
# <a href="https://colab.research.google.com/github/HariRamNarayanan307/colab/blob/main/hari_ramnarayanan_project10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello there")

# %%
# Question 1

# %% [markdown]
# A virtual machince simulates an entire computer and os. This makes it heavy on resources. A container shares the host OS and only contains what is needed for the app. This makes it lighter than VMs.

# %% [markdown]
# A container image is a snapshot of everything an application needs to run, like the OS base and dependencies. A registry is a central server that stores and distributes images.

# %% [markdown]
# Apptainer is designed for environments where users do not have root access while Docker which requires elevated privileges to run.
# <br>
# This makes it much safer on shared systems where many users work side by side.

# %%
# Question 2
